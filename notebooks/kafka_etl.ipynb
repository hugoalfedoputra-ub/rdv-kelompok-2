# %%
import os
from dotenv import load_dotenv

load_dotenv("../pipeline/.env")

COUCHDB_PWD = os.getenv("APP_PASSWORD")

import requests
import json
from kafka import KafkaProducer, KafkaConsumer

# %%
fw_consumer = KafkaConsumer(
    'free-weather',
    bootstrap_servers=['localhost:29092'],
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    value_deserializer=lambda m: json.loads(m.decode('ascii')),
    # remove this parameter for continuous listening
    consumer_timeout_ms=1000
)

ow_consumer = KafkaConsumer(
    'open-weather',
    bootstrap_servers=['localhost:29092'],
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    value_deserializer=lambda m: json.loads(m.decode('ascii')),
    # remove this parameter for continuous listening
    consumer_timeout_ms=1000
)

om_consumer = KafkaConsumer(
    'open-meteo',
    bootstrap_servers=['localhost:29092'],
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    value_deserializer=lambda m: json.loads(m.decode('ascii')),
    # remove this parameter for continuous listening
    consumer_timeout_ms=1000
)

# %%
from pprint import pprint
import datetime
import pycouchdb
import hashlib

server = pycouchdb.Server(f"http://group1:{COUCHDB_PWD}@localhost:5984/", authmethod="basic")
server.info()
# Out:
# {'couchdb': 'Welcome',
#  'version': '3.5.0',
#  'git_sha': '11f0d3643',
#  'uuid': '091bbee99fb1462bca75d5a0409342c3',
#  'features': ['access-ready',
#   'partitioned',
#   'pluggable-storage-engines',
#   'reshard',
#   'scheduler'],
#  'vendor': {'name': 'The Apache Software Foundation'}}

# %%
db_fw = server.database('free_weather')

for message in fw_consumer:
    # print(message.value)
    # print("%s:%d:%d: key=%s" % (message.topic, message.partition, message.offset, message.key))
    data = message.value
    # pprint(data)
    print(data['provider'])

    m = hashlib.sha256()
    last_updated = str(message.timestamp)
    res = ''.join(format(ord(i), '08b') for i in last_updated).encode('utf-8')
    m.update(res)
    id = m.hexdigest()

    ct = datetime.datetime.now()
    print(ct)

    entry = {
        '_id': id,
        'provider': data['provider'],
        'location': data['data']['location'],
        'current_weather': data['data']['current'],
        'created_at': str(ct),
        'last_updated': data['data']['current']['last_updated']
    }

    try:
        res = db_fw.save(entry)
        print(res)
        fw_consumer.commit()
    except Exception as e:
        print(e)
        continue
# Out:
# FreeWeatherAPI
# 2025-05-13 11:09:33.911407
# {'_id': 'a9aefe48d7827c8409c6b287db5dd1b2e1b65182d09bb844b6a73ac5d06200be', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747102983, 'localtime': '2025-05-13 09:23'}, 'current_weather': {'last_updated_epoch': 1747102500, 'last_updated': '2025-05-13 09:15', 'temp_c': 23.1, 'temp_f': 73.5, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 88, 'wind_dir': 'E', 'pressure_mb': 1012.0, 'pressure_in': 29.89, 'precip_mm': 0.02, 'precip_in': 0.0, 'humidity': 88, 'cloud': 94, 'feelslike_c': 25.3, 'feelslike_f': 77.5, 'windchill_c': 23.1, 'windchill_f': 73.5, 'heatindex_c': 25.3, 'heatindex_f': 77.5, 'dewpoint_c': 21.0, 'dewpoint_f': 69.8, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.9, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:33.911407', 'last_updated': '2025-05-13 09:15', '_rev': '1-5c6d17b424d8595f6c25541c746cf6f1'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:34.065090
# {'_id': 'efd5e0c5c2323f62c4568dbe6d3e91a73892f7d188d16e4398280af484421fa7', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747102981, 'localtime': '2025-05-13 09:23'}, 'current_weather': {'last_updated_epoch': 1747102500, 'last_updated': '2025-05-13 09:15', 'temp_c': 23.1, 'temp_f': 73.5, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 88, 'wind_dir': 'E', 'pressure_mb': 1012.0, 'pressure_in': 29.89, 'precip_mm': 0.02, 'precip_in': 0.0, 'humidity': 88, 'cloud': 94, 'feelslike_c': 25.3, 'feelslike_f': 77.5, 'windchill_c': 23.1, 'windchill_f': 73.5, 'heatindex_c': 25.3, 'heatindex_f': 77.5, 'dewpoint_c': 21.0, 'dewpoint_f': 69.8, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.9, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:34.065090', 'last_updated': '2025-05-13 09:15', '_rev': '1-d1970e8bab1dc086ea24fc54a57ca905'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:34.098672
# {'_id': 'c10cc21e0d12667719154b05793130cd0ef960bfdd6a7bd2569978db9aece93c', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747102981, 'localtime': '2025-05-13 09:23'}, 'current_weather': {'last_updated_epoch': 1747102500, 'last_updated': '2025-05-13 09:15', 'temp_c': 23.1, 'temp_f': 73.5, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 88, 'wind_dir': 'E', 'pressure_mb': 1012.0, 'pressure_in': 29.89, 'precip_mm': 0.02, 'precip_in': 0.0, 'humidity': 88, 'cloud': 94, 'feelslike_c': 25.3, 'feelslike_f': 77.5, 'windchill_c': 23.1, 'windchill_f': 73.5, 'heatindex_c': 25.3, 'heatindex_f': 77.5, 'dewpoint_c': 21.0, 'dewpoint_f': 69.8, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.9, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:34.098672', 'last_updated': '2025-05-13 09:15', '_rev': '1-21602338e998d415c57fc674b10c36e2'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:34
 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 167, 'wind_dir': 'SSE', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.22, 'precip_in': 0.01, 'humidity': 88, 'cloud': 73, 'feelslike_c': 26.2, 'feelslike_f': 79.2, 'windchill_c': 24.0, 'windchill_f': 75.2, 'heatindex_c': 26.2, 'heatindex_f': 79.2, 'dewpoint_c': 21.9, 'dewpoint_f': 71.3, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 5.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:49.950845', 'last_updated': '2025-05-13 11:00', '_rev': '1-af4a960d250f04d78b141b8cb7b2c55d'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:50.001434
# {'_id': '57d7089ca86ca64dd2ca984e36cb95cad52cb159a5484caeed7d17a03d4c6b67', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747109173, 'localtime': '2025-05-13 11:06'}, 'current_weather': {'last_updated_epoch': 1747108800, 'last_updated': '2025-05-13 11:00', 'temp_c': 24.0, 'temp_f': 75.2, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 167, 'wind_dir': 'SSE', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.22, 'precip_in': 0.01, 'humidity': 88, 'cloud': 73, 'feelslike_c': 26.2, 'feelslike_f': 79.2, 'windchill_c': 24.0, 'windchill_f': 75.2, 'heatindex_c': 26.2, 'heatindex_f': 79.2, 'dewpoint_c': 21.9, 'dewpoint_f': 71.3, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 5.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:50.001434', 'last_updated': '2025-05-13 11:00', '_rev': '1-df544f22c851074b4a09f2fbddd7e771'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:50.051373
# {'_id': 'cf8f690359be1f24923c446bd618410d14a0627d6f1423e410b47e1a87296555', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747109173, 'localtime': '2025-05-13 11:06'}, 'current_weather': {'last_updated_epoch': 1747108800, 'last_updated': '2025-05-13 11:00', 'temp_c': 24.0, 'temp_f': 75.2, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 167, 'wind_dir': 'SSE', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.22, 'precip_in': 0.01, 'humidity': 88, 'cloud': 73, 'feelslike_c': 26.2, 'feelslike_f': 79.2, 'windchill_c': 24.0, 'windchill_f': 75.2, 'heatindex_c': 26.2, 'heatindex_f': 79.2, 'dewpoint_c': 21.9, 'dewpoint_f': 71.3, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 5.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:50.051373', 'last_updated': '2025-05-13 11:00', '_rev': '1-855e833485319a2ae3aab42e62fbb163'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:50.102224
# {'_id': 'a60e8159e6821dd131954005b3736b0088dffee2599bbd493578e3c8f98afab8', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747109173, 'localtime': '2025-05-13 11:06'}, 'current_weather': {'last_updated_epoch': 1747108800, 'last_updated': '2025-05-13 11:00', 'temp_c': 24.0, 'temp_f': 75.2, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 167, 'wind_dir': 'SSE', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.22, 'precip_in': 0.01, 'humidity': 88, 'cloud': 73, 'feelslike_c': 26.2, 'feelslike_f': 79.2, 'windchill_c': 24.0, 'windchill_f': 75.2, 'heatindex_c': 26.2, 'heatindex_f': 79.2, 'dewpoint_c': 21.9, 'dewpoint_f': 71.3, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 5.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:50.102224', 'last_updated': '2025-05-13 11:00', '_rev': '1-73e3636ffef578f52519757d1f815eb7'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:50.150438
# {'_id': 'a6ed2323b63cd5d171958f00839406867d69c704d349c27f4eaa71d62f985b6f', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747109173, 'localtime': '2025-05-13 11:06'}, 'current_weather': {'last_updated_epoch': 1747108800, 'last_updated': '2025-05-13 11:00', 'temp_c': 24.0, 'temp_f': 75.2, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 167, 'wind_dir': 'SSE', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.22, 'precip_in': 0.01, 'humidity': 88, 'cloud': 73, 'feelslike_c': 26.2, 'feelslike_f': 79.2, 'windchill_c': 24.0, 'windchill_f': 75.2, 'heatindex_c': 26.2, 'heatindex_f': 79.2, 'dewpoint_c': 21.9, 'dewpoint_f': 71.3, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 5.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:50.150438', 'last_updated': '2025-05-13 11:00', '_rev': '1-b85e78ff88f0d5c2456cd529a1bdfd5d'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:50.202194
# {'_id': 'd9eb590920fe9d6c632d1d9971ff8bcd4108fa9f17842676e6fedcdb51aeaf31', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747109173, 'localtime': '2025-05-13 11:06'}, 'current_weather': {'last_updated_epoch': 1747108800, 'last_updated': '2025-05-13 11:00', 'temp_c': 24.0, 'temp_f': 75.2, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 167, 'wind_dir': 'SSE', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.22, 'precip_in': 0.01, 'humidity': 88, 'cloud': 73, 'feelslike_c': 26.2, 'feelslike_f': 79.2, 'windchill_c': 24.0, 'windchill_f': 75.2, 'heatindex_c': 26.2, 'heatindex_f': 79.2, 'dewpoint_c': 21.9, 'dewpoint_f': 71.3, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 5.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:50.202194', 'last_updated': '2025-05-13 11:00', '_rev': '1-a8a7afcbb13de56e10993d1de3eac331'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:50.254247
# {'_id': 'a16cbe9225b28b4eb8bb4fdab52a11530e2091876b521e7efab8111210f34e57', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747109381, 'localtime': '2025-05-13 11:09'}, 'current_weather': {'last_updated_epoch': 1747108800, 'last_updated': '2025-05-13 11:00', 'temp_c': 24.0, 'temp_f': 75.2, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 167, 'wind_dir': 'SSE', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.22, 'precip_in': 0.01, 'humidity': 88, 'cloud': 73, 'feelslike_c': 26.2, 'feelslike_f': 79.2, 'windchill_c': 24.0, 'windchill_f': 75.2, 'heatindex_c': 26.2, 'heatindex_f': 79.2, 'dewpoint_c': 21.9, 'dewpoint_f': 71.3, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 5.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:50.254247', 'last_updated': '2025-05-13 11:00', '_rev': '1-b87708a43b127f0d8f341bf9c1c299d1'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:50.312629
# {'_id': 'bb2d5e69d56567da4303b052f3a6e8ad5488d5d75b58ae5b6137268637adf21d', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747109381, 'localtime': '2025-05-13 11:09'}, 'current_weather': {'last_updated_epoch': 1747108800, 'last_updated': '2025-05-13 11:00', 'temp_c': 24.0, 'temp_f': 75.2, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 167, 'wind_dir': 'SSE', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.22, 'precip_in': 0.01, 'humidity': 88, 'cloud': 73, 'feelslike_c': 26.2, 'feelslike_f': 79.2, 'windchill_c': 24.0, 'windchill_f': 75.2, 'heatindex_c': 26.2, 'heatindex_f': 79.2, 'dewpoint_c': 21.9, 'dewpoint_f': 71.3, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 5.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:50.312629', 'last_updated': '2025-05-13 11:00', '_rev': '1-c584c7c0fa61d60f719e926580f9aa0a'}
# Requires group_id
# FreeWeatherAPI
# 2025-05-13 11:09:50.362148
# {'_id': '0141e799e7302aba857ce9f4abf5da8d5b1c7486a78a7f329720dbe471454fc0', 'provider': 'FreeWeatherAPI', 'location': {'name': 'Malang', 'region': 'East Java', 'country': 'Indonesia', 'lat': -7.98, 'lon': 112.63, 'tz_id': 'Asia/Jakarta', 'localtime_epoch': 1747109381, 'localtime': '2025-05-13 11:09'}, 'current_weather': {'last_updated_epoch': 1747108800, 'last_updated': '2025-05-13 11:00', 'temp_c': 24.0, 'temp_f': 75.2, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 167, 'wind_dir': 'SSE', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.22, 'precip_in': 0.01, 'humidity': 88, 'cloud': 73, 'feelslike_c': 26.2, 'feelslike_f': 79.2, 'windchill_c': 24.0, 'windchill_f': 75.2, 'heatindex_c': 26.2, 'heatindex_f': 79.2, 'dewpoint_c': 21.9, 'dewpoint_f': 71.3, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 5.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'created_at': '2025-05-13 11:09:50.362148', 'last_updated': '2025-05-13 11:00', '_rev': '1-cda715c2a8159996574a329d797ae532'}
# Requires group_id

# %%
db_ow = server.database('open_weather')

for message in ow_consumer:
    data = message.value
    # pprint(data)
    print(data['provider'])

    ct = datetime.datetime.now()

    m = hashlib.sha256()
    last_updated = str(datetime.datetime.fromtimestamp(data['data']['dt']))
    res = ''.join(format(ord(i), '08b') for i in last_updated).encode('utf-8')
    m.update(res)
    id = m.hexdigest()

    entry = {
        '_id': id,
        'provider': data['provider'],
        'location': {
            'lat': data['data']['coord']['lat'],
            'lon': data['data']['coord']['lon'],
            'name': data['data']['name'],
            'country': data['data']['sys']['country']
        },
        'current_weather': {
            'clouds': data['data']['clouds'],
            'main': {
                'feels_like': data['data']['main']['feels_like'],
                'pressure_ground_level': data['data']['main']['grnd_level'],
                'humidity': data['data']['main']['humidity'],
                'pressure': data['data']['main']['pressure'],
                'sea_level': data['data']['main']['sea_level'],
                'temp': data['data']['main']['temp'],
                'visibility': data['data']['visibility'],
                'wind_dir': data['data']['wind']['deg'],
                'wind_speed': data['data']['wind']['speed'],
                'wind_gust': data['data']['wind']['gust']
            },
            'weather': data['data']['weather'],
        },
        'created_at': str(ct),
        'last_updated': str(datetime.datetime.fromtimestamp(data['data']['dt']))
    }

    try:
        res = db_ow.save(entry)
        print(res)
        ow_consumer.commit()
    except Exception as e:
        print(e)
        continue
# Out:
# OpenWeatherMap
# Document update conflict.
# OpenWeatherMap
# Document update conflict.
# OpenWeatherMap
# Document update conflict.
# OpenWeatherMap
# Document update conflict.
# OpenWeatherMap
# Document update conflict.
# OpenWeatherMap
# Document update conflict.
# OpenWeatherMap
# {'_id': '7863f51862069785b0a83aaccc8ee49628e7447654947c59daf87175a482becc', 'provider': 'OpenWeatherMap', 'location': {'lat': -7.95, 'lon': 112.61, 'name': 'Malang', 'country': 'ID'}, 'current_weather': {'clouds': {'all': 87}, 'main': {'feels_like': 311.15, 'pressure_ground_level': 920, 'humidity': 90, 'pressure': 1011, 'sea_level': 1011, 'temp': 304.15, 'visibility': 6808, 'wind_dir': 227, 'wind_speed': 0.6, 'wind_gust': 1.2}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, 'created_at': '2025-05-13 11:09:51.760005', 'last_updated': '2025-05-13 11:00:01', '_rev': '1-a502588a99a12d67b14433686a2a02d3'}
# Requires group_id

# %%
db_om = server.database('open_meteo')

for message in om_consumer:
    data = message.value
    # pprint(data)
    print(data['provider'])

    m = hashlib.sha256()
    last_updated = str(message.timestamp)
    res = ''.join(format(ord(i), '08b') for i in last_updated).encode('utf-8')
    m.update(res)
    id = m.hexdigest()

    ct = datetime.datetime.now()
    print(ct)

    entry = {
        '_id': id,
        'provider': data['provider'],
        'location': {
            'lat': data['latitude'],
            'lon': data['longitude'],
            'grid_lat': data['data']['latitude'],
            'grid_lon': data['data']['longitude']
        },
        'current_weather': data['data']['current'],
        'created_at': str(ct),
        'last_updated': data['data']['current']['time']
    }

    try:
        res = db_om.save(entry)
        print(res)
        om_consumer.commit()
    except Exception as e:
        print(e)
        continue
# Out:
# Open-Meteo
# 2025-05-13 11:10:46.970684
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.017325
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.077578
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.126588
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.176884
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.229255
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.298484
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.346888
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.396468
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.446217
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.496632
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.546514
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.597295
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.648048
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.699379
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.747777
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.807418
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.856409
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.907412
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:47.956384
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.007302
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.056646
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.116481
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.166797
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.217366
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.266847
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.317312
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.367385
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.417202
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.466760
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.526279
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.576707
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.628631
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.687805
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.748194
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.797855
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.847637
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.897395
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.948136
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:48.998725
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.057796
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.106378
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.156658
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.206605
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.257080
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.306514
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.357154
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.416517
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.466981
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.516798
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.566332
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.617074
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.666457
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.717626
# Document update conflict.
# Open-Meteo
# 2025-05-13 11:10:49.767337
# {'_id': '2c48c9345e15c3a02e2c3035e2879725df2b5cc55527abce3ac715f94324f593', 'provider': 'Open-Meteo', 'location': {'lat': -7.95, 'lon': 112.61, 'grid_lat': -8.0, 'grid_lon': 112.625}, 'current_weather': {'time': '2025-05-13T11:00', 'interval': 900, 'temperature_2m': 28.6, 'apparent_temperature': 32.9, 'relative_humidity_2m': 63, 'rain': 0.0, 'precipitation': 0.0, 'weather_code': 2, 'cloud_cover': 81, 'showers': 0.0, 'wind_speed_10m': 1.8, 'wind_direction_10m': 53, 'pressure_msl': 1010.8, 'surface_pressure': 955.2, 'wind_gusts_10m': 5.8}, 'created_at': '2025-05-13 11:10:49.767337', 'last_updated': '2025-05-13T11:00', '_rev': '1-cac353c5197cadc83139427251db2016'}
# Requires group_id
